# %% [markdown]
# ### 用分水岭算法实现图像的分割与提取

# %%
#利用形态学变换进行获取图像边界
#运用腐蚀操作然后进行相减
import cv2
import numpy as np
import matplotlib.pyplot as plt
o = cv2.imread("E:\\opencv\\txcl\\tu.png")
k = np.ones((5,5), np.uint8)
e = cv2.erode(o, k)
b = cv2.subtract(o, e)
plt.subplot(131), plt.imshow(o), plt.axis("off")
plt.subplot(132), plt.imshow(e), plt.axis("off")
plt.subplot(133), plt.imshow(b), plt.axis("off")
# Out:
# (<AxesSubplot:>,
# ...
#  (-0.5, 506.5, 503.5, -0.5))

# %% [markdown]
# 距离变换函数
# dst = cv2.distanceTransform(src, distancrType, maskSize[, dstType])
# - src是8位单通道的二值图像
# - distancrType距离类型参数
# ![image.png](attachment:image.png)
# - maskSize掩膜尺寸
# ![image-2.png](attachment:image-2.png)
# - dst计算得到的目标图像

# %%
import numpy as np       
import cv2       
import matplotlib.pyplot as plt        
img = cv2.imread("E:\\opencv\\txcl\\coin.png")        
gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)   #将图像变为灰度值     
img=cv2.cvtColor(img, cv2.COLOR_BGR2RGB)        
ishow=img.copy()       
ret, thresh = cv2.threshold(gray,0,255, cv2.THRESH_BINARY_INV+cv2.THRESH_OTSU)        
kernel = np.ones((3,3), np.uint8)      
opening = cv2.morphologyEx(thresh, cv2.MORPH_OPEN, kernel, iterations = 2)       
dist_transform = cv2.distanceTransform(opening, cv2.DIST_L2,5)      
ret, fore = cv2.threshold(dist_transform,0.7*dist_transform.max(),255,0)       
plt.subplot(131)       
plt.imshow(ishow)       
plt.axis('off')      
plt.subplot(132)        
plt.imshow(dist_transform)
plt.axis('off')       
plt.subplot(133)       
plt.imshow(fore)    
plt.axis('off')
# Out:
# (-0.5, 318.5, 394.5, -0.5)

# %% [markdown]
# ## 视频处理
# retval, image = cv2.VideoCapture.read()
# - retval表示是否捕获成功
# - image返回捕获到的帧

# %%
import numpy as np
import cv2
cap = cv2.VideoCapture(0)
while(cap.isOpened()):
    ret, frame = cap.read()
    cv2.imshow("frame", frame)
    c = cv2.waitKey(1)
    if c==27:
        break
cap.release()
cv2.destroyAllWindows()

# %%
import numpy as np
import cv2
cap = cv2.VideoCapture("E:\\opencv\\txcl\\test.mp4")
while(cap.isOpened()):
    ret, frame = cap.read()
    frame = cv2.Canny(frame, 100, 200)
    cv2.imshow("frame", frame)
    c = cv2.waitKey(25)
    if c==27:
        break
cap.release()
cv2.destroyAllWindows()

# %% [markdown]
# ## 捕获帧
# retval, image = cv2.VideoCapture.read()
# - image是返回的捕获到的帧如果没有帧则该值为空
# - retval表示捕获是否成功
# ## 设置属性
# retval = cv2.VideoCapture.get(propId)
# - propId对应着类对象的属性
# ![image.png](attachment:image.png)

# %%
test =np.vstack([[3,4],[5, 6]])
test.shape
# Out:
# (2, 2)
